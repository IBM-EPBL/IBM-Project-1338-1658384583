# %% [markdown]
# Team ID      :	PNT2022TMID48059
#
# Project Name :	Project – Emerging Methods For Early
# Detection Of Forest  Fires
# # **Video Analysis**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import librosa
from tensorflow.keras.preprocessing import image
from keras.models import load_model
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
cap = cv2.VideoCapture('/content/Pexels Videos 2715412.mp4')
 
# Check if camera opened successfully
if (cap.isOpened()== False): 
  print("Error opening video stream or file")
 
# Read until video is completed
while(cap.isOpened()):
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
    x=image.img_to_array(frame)
    res=cv2.resize(x,dsize=(64,64),interpolation=cv2.INTER_CUBIC)
    #expand the image shape
    x=np.expand_dims(res,axis=0)
    model=load_model("/content/forest.h5")
    cv2_imshow(frame)
    pred=model.predict(x)
    pred = int(pred[0][0])
    pred
    int(pred)
    if pred==0:
      print('Forest fire')
      break
    else:
      print("no danger")
      break
 
# When everything done, release the video capture object
cap.release()
 
# Closes all the frames
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=3840x2160 at 0x7FF5D85C8350>
# 1/1 [==============================] - 0s 66ms/step
# Forest fire

# %% [markdown]
# # **Sending Alert Message**

# %%
pip install twilio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install playsound
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pygobject
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from twilio.rest import Client
from playsound import playsound
if pred==0:
  account_sid='AC474064ae12bddff4cf0d03c79fbf7ce5'
  auth_token='149d08673e4b9c4c18fb8121bb904c91'
  client=Client(account_sid,auth_token)
  message=client.messages \
  .create(
      body='forest fire is detected,stay alert',
      #use twilio free number
      from_='+17174938392',
      #to number
      to='+916382435343')
  print(message.sid)
  print("Fire detected")
  print("SMS Sent!")
elif pred==1:
  print('No danger')
# Out:
# SM415e3800f87b0f296904ad14d8415ebe
# Fire detected
# SMS Sent!

# %%
import cv2 
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import librosa
from tensorflow.keras.preprocessing import image
from keras.models import load_model
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
cap = cv2.VideoCapture('/content/Pexels Videos 2715412.mp4')
 
# Check if camera opened successfully
if (cap.isOpened()== False): 
  print("Error opening video stream or file")
 
# Read until video is completed
while(cap.isOpened()):
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
    x=image.img_to_array(frame)
    res=cv2.resize(x,dsize=(64,64),interpolation=cv2.INTER_CUBIC)
    #expand the image shape
    x=np.expand_dims(res,axis=0)
    model=load_model("/content/forest.h5")
    cv2_imshow(frame)
    pred=model.predict(x)
    pred = int(pred[0][0])
    pred
    int(pred)
    if pred==0:
        account_sid='AC474064ae12bddff4cf0d03c79fbf7ce5'
        auth_token='149d08673e4b9c4c18fb8121bb904c91'
        client=Client(account_sid,auth_token)
        message=client.messages \
        .create(
        body='forest fire is detected,stay alert',
        #use twilio free number
        from_='+17174938392',
        #to number
       to='+916382435343')
        print(message.sid)
        print("Fire detected")
        print("SMS Sent!")
        break
    elif pred==1:
        print('No danger')
        break

       # When everything done, release the video capture object
    cap.release()
 
       # Closes all the frames
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=3840x2160 at 0x7FF5D7DCE0D0>
# 1/1 [==============================] - 0s 49ms/step
# SMa8691afd1f5f0acd735a8452a089a80b
# Fire detected
# SMS Sent!
